# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-matplotlib" data-toc-modified-id="Import-matplotlib-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import matplotlib</a></span></li><li><span><a href="#plot-the-lines" data-toc-modified-id="plot-the-lines-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>plot the lines</a></span></li><li><span><a href="#legend" data-toc-modified-id="legend-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>legend</a></span></li><li><span><a href="#line-style" data-toc-modified-id="line-style-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>line style</a></span></li><li><span><a href="#theme-style" data-toc-modified-id="theme-style-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>theme style</a></span></li><li><span><a href="#Adjust-the-marker" data-toc-modified-id="Adjust-the-marker-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Adjust the marker</a></span></li><li><span><a href="#scatter" data-toc-modified-id="scatter-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>scatter</a></span></li><li><span><a href="#errorbar" data-toc-modified-id="errorbar-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>errorbar</a></span></li><li><span><a href="#Contour" data-toc-modified-id="Contour-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Contour</a></span></li><li><span><a href="#histogram" data-toc-modified-id="histogram-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>histogram</a></span></li><li><span><a href="#imshow" data-toc-modified-id="imshow-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>imshow</a></span></li><li><span><a href="#axes" data-toc-modified-id="axes-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>axes</a></span></li><li><span><a href="#subplots" data-toc-modified-id="subplots-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>subplots</a></span></li><li><span><a href="#subplot" data-toc-modified-id="subplot-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>subplot</a></span></li><li><span><a href="#text" data-toc-modified-id="text-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>text</a></span></li><li><span><a href="#annotate" data-toc-modified-id="annotate-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>annotate</a></span></li><li><span><a href="#xscale-yscale" data-toc-modified-id="xscale-yscale-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>xscale yscale</a></span></li><li><span><a href="#set_major_locator-set_major_formatter" data-toc-modified-id="set_major_locator-set_major_formatter-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>set_major_locator set_major_formatter</a></span></li><li><span><a href="#ax.set_" data-toc-modified-id="ax.set_-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>ax.set_</a></span></li><li><span><a href="#3d-figure" data-toc-modified-id="3d-figure-20"><span class="toc-item-num">20&nbsp;&nbsp;</span>3d figure</a></span></li><li><span><a href="#sns" data-toc-modified-id="sns-21"><span class="toc-item-num">21&nbsp;&nbsp;</span>sns</a></span></li></ul></div>

# %% [markdown]
# ## Import matplotlib

# %%
import matplotlib.pyplot as plt

#Extra 
import pandas as pd
import numpy as np

# %% [markdown]
# ## plot the lines

# %%
x = (1, 2, 3)
y = (4, 5, 6)
plt.plot(*zip(x, y))
plt.show()

# %%
data = pd.Series(np.arange(3))
data.plot(alpha=0.5, style='-o')

# %%
x = pd.Series(np.arange(20), index=pd.date_range(
    '2017-07-19', periods=20, freq='D'))
rolling = x.rolling(3, center=True)
data = pd.DataFrame({'input': x, 'four-day rolling-mean': rolling.
                     aggregate('sum'), 'four-day-rolling-std': rolling.std()})

# %%
x = np.linspace(0, 10, 1000)
# plt.subplots() : Create a figure and a set of subplots.
# return fig ,ax
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine')
ax.plot(x, np.cos(x), '--r', label='Consine')
# 'equal' :Set equal scaling (i.e., make circles circular) by changing axis limits.
ax.axis('equal')
leg=ax.legend()

# %% [markdown]
# ## legend

# %%
#borderpad :The fractional whitespace inside the legend border.
#framealpha:Control the alpha transparency of the legend's background.
ax.legend(loc='upper left', frameon=True,
          framealpha=1, borderpad=1, edgecolor='black')
fig

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x[:, np.newaxis]+np.pi*np.arange(0, 2, 0.5))
lines = plt.plot(x, y)
plt.axis('equal')
plt.legend(lines[:2], ['first', 'second'], frameon=True,
           edgecolor='black', title='order')

# %%
fig,ax=plt.subplots()
lines=[]
style=['-','--','-.',':']
x = np.linspace(0, 10, 1000)
for i in range(4):
    lines+=ax.plot(x,np.sin(x-i*np.pi/2),style[i],color='black')
print(lines)
# Out:
# [<matplotlib.lines.Line2D object at 0x11a799e80>, <matplotlib.lines.Line2D object at 0x119cd7748>, <matplotlib.lines.Line2D object at 0x119cd7a90>, <matplotlib.lines.Line2D object at 0x119cd7630>]

# %% [markdown]
# ## line style

# %%
ax = data.plot(style=['-', '--', ':'])
ax.lines[0].set_alpha = 0.1
plt.ylabel('Hello'); plt.xlabel('Hey'); plt.title('$sigma_1$')
# Out:
# Text(0.5, 1.0, '$sigma_1$')

# %% [markdown]
# ## theme style

# %%
plt.style.available
# Out:
# ['seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-ticks',
#  'fivethirtyeight',
#  'seaborn-whitegrid',
#  'classic',
#  '_classic_test',
#  'fast',
#  'seaborn-talk',
#  'seaborn-dark-palette',
#  'seaborn-bright',
#  'seaborn-pastel',
#  'grayscale',
#  'seaborn-notebook',
#  'ggplot',
#  'seaborn-colorblind',
#  'seaborn-muted',
#  'seaborn',
#  'Solarize_Light2',
#  'seaborn-paper',
#  'bmh',
#  'tableau-colorblind10',
#  'seaborn-white',
#  'dark_background',
#  'seaborn-poster',
#  'seaborn-deep']

# %%
plt.style.use('classic')

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x))

# %% [markdown]
# ## Adjust the marker

# %%
plt.style.use('fivethirtyeight')
x = np.linspace(0, 10, 30)
y = np.sin(x)
plt.plot(x, y, '-p', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)

# %% [markdown]
# ## scatter

# %%
x=np.random.randn(100)
y=np.random.randn(100)
colors=np.random.rand(100)
size=1000*np.random.rand(100)
plt.scatter(x,y,c=colors,s=size,cmap='viridis') #cmap means give figure color style
plt.colorbar()

# %% [markdown]
# ## errorbar
# Plot y versus x as lines and/or markers with attached errorbars.
# 會上下偏差的範圍

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x)+dy*np.random.randn(50)  
plt.errorbar(x, y, yerr=dy, fmt='.k', elinewidth=1) #fmt The format for the data points / data lines
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
#capsize: The length of the error bar caps in points
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
             ecolor='lightgray', elinewidth=3, capsize=30)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## Contour

# %%
x=np.linspace(0,5,50)
y=np.linspace(0,5,40)

xx,yy=np.meshgrid(x,y)
z=np.sin(xx)**10+np.cos(10+yy*xx)*np.cos(xx)

# %%
plt.contour(x, y, z, colors='black')

# %%
#origin : Place the [0,0] index of the array in the upper left or lower left corner of the axes
plt.imshow(z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy')

# %%
# levels : Determines the number and positions of the contour lines / regions.
contours = plt.contour(xx, yy, z, levels=3, colors='black')
# inline=True   If ``True`` the underlying contour is removed where the label is placed
plt.clabel(contours, inline=True, fontsize=8)
plt.imshow(z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy', alpha=0.5)
plt.colorbar()

# %% [markdown]
# ## histogram
# Plot a histogram

# %%
plt.figure(figsize=(10,4))
data=np.random.randn(1000)
plt.hist(data)
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.hist(data, bins=30, density=True, alpha=0.5,
         histtype='stepfilled', color='steelblue',
         edgecolor='red')
plt.show()

# %%
x1=np.random.normal(0,0.8,1000)
x2=np.random.normal(-2,1,1000)
x3=np.random.normal(3,2,1000)
kwargs=dict(histtype='stepfilled',alpha=0.3,density=True,bins=40)
plt.hist(x1,**kwargs)
plt.hist(x2,**kwargs)
plt.hist(x3,**kwargs)
plt.show()

# %% [markdown]
# ## imshow

# %%
x=np.linspace(0,10,1000)
y=np.sin(x)*np.cos(x[:,np.newaxis])
plt.imshow(y,cmap='gray')
plt.colorbar()

# %% [markdown]
# ## axes
# Add an axes to the current figure and make it the current axes.

# %%
ax1=plt.axes()
ax2=plt.axes([0.65,0.65,0.2,0.2])

# %%
fig=plt.figure()
ax=plt.axes([0.1,0.1,0.8,0.4])
ax2=plt.axes([0.1,0.6,0.8,0.4],xticklabels=[])

# %%
ax.plot(np.arange(10))
ax2.plot(np.arange(10))
fig

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4], xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4], ylim=(-1.2, 1.2))
x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %% [markdown]
# ## subplots

# %%
fig,(ax1,ax2)=plt.subplots(2,1)
ax1.plot(np.arange(12))
ax2.plot(np.random.randint(1,10,12))

# %% [markdown]
# ## subplot

# %%
for i in range(1,7):
    plt.subplot(2,3,i)
    plt.text(0.5,0.5,str((2,3,i)),fontsize=18,ha='center')

# %%
fig=plt.figure()
fig.subplots_adjust(hspace=0.4,wspace=0.4)
for i in range(1,7):
    ax=fig.add_subplot(2,3,i)
    ax.text(0.5,0.5,str((2,3,i)),fontsize=19,ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')
for i in range(2):
    for j in range(3):
        ax[i,j].text(0.5,0.5,str((i,j)),fontsize=18,ha='center')

# %%
grid=plt.GridSpec(2,3,wspace=0.4,hspace=0.4)
plt.subplot(grid[0,0])
plt.subplot(grid[0,1:])
plt.subplot(grid[1,:2])
plt.subplot(grid[1,2])

# %%
fig,ax=plt.subplots(1,2,figsize=(11,4))
ax[0].hist(np.random.randn(1000))
for i in range(3):
    ax[1].plot(np.random.rand(10))
ax[1].legend(labels=['a','b','c'],loc='lower left')

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=maxin_ax)
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)
x_hist.hist(x, 40, histtype='stepfilled', orientation='vertical', color='gray')
x_hist.invert_yaxis()  # invert the subplot
y_hist.hist(x, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %% [markdown]
# ## text

# %%
fig,ax=plt.subplots(facecolor='lightgray')
ax.axis([0,10,0,10])
ax.text(1,5,'. Data: (1,5)',transform=ax.transData)
ax.text(0.5,0.1,'. Axes: (0.5,0.1)',transform=ax.transAxes)
ax.text(0.2,0.2,'. Figure: (0.2,0.2)',transform=fig.transFigure)
# Out:
# Text(0.2, 0.2, '. Figure: (0.2,0.2)')

# %%
x = np.linspace(0, 20, 1000)
plt.plot(x,np.cos(x))
plt.text(x=15,y=0.25,s='This is me.',fontdict={'ha':'left','size':'large'})
# Out:
# Text(15, 0.25, 'This is me.')

# %% [markdown]
# ## annotate

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.axis('equal')
ax.annotate('local maxmium', xy=(6.28, 1), xytext=(10, 4),
            arrowprops=dict(facecolor='black', shrink=0.05)) #shrink:  Fraction of total length to shrink from both ends shrink为箭頭的長度(shrink越小越长)
ax.annotate('local minimum', xy=(5*np.pi, -1), xytext=(2, -6),
            arrowprops=dict(connectionstyle='angle3,angleA=0,angleB=-90',width=3),backgroundcolor='yellow')
# Out:
# Text(2, -6, 'local minimum')

# %%
births = pd.read_csv('births.csv')
quartiles = np.percentile(births['births'], [25, 50, 75])
mu, sig = quartiles[1], 0.74*(quartiles[2]-quartiles[0])
births = births.query('(births>@mu-5*@sig) & (births<@mu+5*@sig)')
births['day'] = births['day'].astype(int)
births.index = pd.to_datetime(
    10000*births.year+100*births.month+births.day, format='%Y%m%d')
births_by_date = births.pivot_table(
    'births', [births.index.month, births.index.day])
births_by_date.index = [pd.datetime(2012, month, day)
                        for (month, day) in births_by_date.index]

# %%
fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax)
# textcoords =' offset points' :Offset (in points) from the *xy* value 根據給的數字與xy來抵消
ax.annotate("New Year's Day", xy=('2012-1-1', 4100), xycoords='data',
            xytext=(50, -30), textcoords='offset points', arrowprops=dict(facecolor='black'))

ax.annotate('Independence Day', xy=('2012-7-4', 4250), xycoords='data', bbox=dict(boxstyle='round', fc='none', ec='gray'),
            xytext=(10, -40), textcoords='offset points', ha='center', arrowprops=dict(facecolor='black'))

ax.annotate('Labor Day', xy=('2012-9-4', 4850), xycoords='data', ha='center',
            xytext=(0, -20), textcoords='offset points')

ax.annotate('', xy=('2012-9-1', 4850), xytext=('2012-9-7', 4850),
            xycoords='data', textcoords='data',
            arrowprops={'arrowstyle': '|-|,widthA=0.2,widthB=0.2', })

ax.annotate('Halloween', xy=('2012-10-31', 4600),  xycoords='data',
            xytext=(-80, -40), textcoords='offset points',
            arrowprops=dict(arrowstyle="fancy",
                            fc="0.6", ec="none",
                            connectionstyle="angle3,angleA=0,angleB=-90"))

ax.annotate('Thanksgiving', xy=('2012-11-25', 4500),  xycoords='data',
            xytext=(-120, -60), textcoords='offset points',
            bbox=dict(boxstyle="round4,pad=.5", fc="0.9"),
            arrowprops=dict(facecolor='black'))

ax.annotate('Christmas', xy=('2012-12-25', 3850),  xycoords='data',
            xytext=(-30, 0), textcoords='offset points',
            size=13, ha='right', va="center", #va:在框框的垂直方向上
            bbox=dict(boxstyle="round", alpha=0.1),
            arrowprops=dict(alpha=0.1))
# Out:
# Text(-30, 0, 'Christmas')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris = sns.load_dataset('iris')

plt.figure(figsize=(10,10))
g = sns.regplot(x='sepal_length', y='sepal_width',data=iris, scatter_kws={'s': 2})
for _, row in iris.iterrows():
    sepal_length, sepal_width, petal_length, petal_width, species = row
    g.annotate(f'({petal_length},{petal_width})',(sepal_length,sepal_width),size=10)

# %% [markdown]
# ## xscale yscale

# %%
ax=plt.axes(xscale='log',yscale='log')

# %% [markdown]
# ## set_major_locator set_major_formatter

# %%
ax=plt.axes()
ax.plot(np.random.rand(50))
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig,ax=plt.subplots()
x=np.linspace(0,3*np.pi,1000)
ax.plot(x,np.sin(x),lw=3,label='Sine')
ax.plot(x,np.cos(x),lw=3,label='Cosine')
ax.grid(True)
ax.legend(frameon=True)
ax.axis('equal')
ax.set_xlim(0,3*np.pi)
# Out:
# (0, 9.42477796076938)

# %%
#Set a tick on each integer multiple of a base within the view interval.
ax.xaxis.set_major_locator(plt.MultipleLocator(np.pi/2))
ax.yaxis.set_major_locator(plt.MultipleLocator(np.pi/4))
fig

# %% [markdown]
# ## ax.set_

# %%
ax = plt.axes()
ax.set_axisbelow(True)
plt.grid(color='r', linestyle='solid')
for spine in ax.spines.values():
    spine.set_visible(False)
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(colors='yellow', direction='out')
for tick in ax.get_xticklabels():
    tick.set_color('blue')
for tick in ax.get_yticklabels():
    tick.set_color('blue')
ax.hist(np.random.randn(1000), edgecolor='#E6E6E6', color='#EE6666')
plt.show()

# %% [markdown]
# ## 3d figure

# %%
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
ax=plt.axes(projection='3d')
zline=np.linspace(0,15,1000)
xline=np.sin(zline)
yline=np.cos(zline)
ax.plot3D(xline,yline,zline,'gray')
zdata=15*np.random.random(100)
xdata=np.sin(zdata)+0.1*np.random.randn(100)
ydata=np.cos(zdata)+0.1*np.random.randn(100)
ax.scatter3D(xdata,ydata,zdata,c=zdata,cmap='Greens')

# %%
def f(x,y):
    return np.sin(np.sqrt(x**2+y**2))

x=np.linspace(-6,6,30)
y=np.linspace(-6,6,30)
x,y=np.meshgrid(x,y)
z=f(x,y)

# %%
fig=plt.figure()
ax=plt.axes(projection='3d')
ax.contour3D(x,y,z,50,cmap='binary')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
#'elev' stores the elevation angle in the z plane.
#'azim' stores the azimuth angle in the x,y plane.
ax.view_init(60,35)
fig

# %%
# Plot a 3D wireframe.
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_wireframe(x, y, z, color='black')
ax.set_title('wireframe')
# Out:
# Text(0.5, 0.92, 'wireframe')

# %%
#Create a surface plot.
ax = plt.axes(projection='3d')
#rstride : Downsampling stride in each direction. 
ax.plot_surface(x, y, z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
ax.set_title('surface')
# Out:
# Text(0.5, 0.92, 'surface')

# %%
r = np.linspace(0, 6, 20)
theta = np.linspace(-0.9*np.pi, 0.8*np.pi, 40)
r, theta = np.meshgrid(r, theta)
x = r*np.sin(theta)
y = r*np.cos(theta)
z = f(x, y)
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')

# %%
from matplotlib.tri import Triangulation
theta = np.linspace(0, 2*np.pi, 30)
w = np.linspace(-0.25, 0.25, 8)
w, theta = np.meshgrid(w, theta)
phi = 0.5*theta

r = 1+w*np.cos(phi)
x = np.ravel(r*np.cos(theta))
y = np.ravel(r*np.sin(theta))
z = np.ravel(w*np.sin(phi))
# triangulate in the underlying parameterization
tri = Triangulation(np.ravel(w), np.ravel(theta))
ax = plt.axes(projection='3d')
ax.plot_trisurf(x, y, z, triangles=tri.triangles,
                cmap='viridis', linewidths=0.2)
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_zlim(-1, 1)
# Out:
# (-1, 1)

# %% [markdown]
# ## sns

# %%
import seaborn as sns

# %%
sns.set_style('ticks')

# %% [markdown]
# ### regplot

# %%
for num,style in enumerate(['darkgrid','whitegrid','dark','white','ticks']):
    plt.subplot(2,3,num+1)
    sns.set_style(style)
    sns.regplot(x=np.arange(10),y=np.arange(10))
    plt.title(f'{style}')

# %% [markdown]
# ### lmplot

# %%
tips = sns.load_dataset('tips')
g = sns.lmplot(x='tip',
                    y='total_bill',
                    data=tips,
                    aspect=2) # length/height ratio
g = (g.set_axis_labels('Tip', 'Total_bill(USD)')).set(xlim=(0, 10), ylim=(0, 100), title='hello')

# %% [markdown]
# ### scatterplot

# %%
df=pd.DataFrame({'hello': np.arange(100), 'world': np.random.randint(
    1, 10, 100), 'Jacky': np.random.normal(loc=0, scale=5,size=100)})
color=['red' if hey==1 else 'green' for hey in df.hello]
plt.subplot(1,2,1)
sns.regplot(x='world',y='Jacky',data=df,fit_reg=False,scatter_kws={'facecolor':color})
plt.subplot(1,2,2)
sns.scatterplot(x='world',y='Jacky',data=df,hue=color)

# %% [markdown]
# ### kdeplot

# %%
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])
for col in 'xy':
    sns.kdeplot(data[col], shade=True)

# %% [markdown]
# ### barplot

# %%
#dodge=True,當使用hue時，元素是否應沿著它移動分類軸。
data = pd.DataFrame({'x': np.arange(10), 'y': np.random.randint(10, 20, 10),'z':np.random.choice([1,2],size=10)})

fig,(ax1,ax2) = plt.subplots(1,2)
fig.subplots_adjust(wspace=1)
sns.barplot(x='x', y='y' ,hue='z',data=data, dodge=False,ax=ax1)
sns.barplot(x='x', y='y' ,hue='z',data=data, dodge=True,ax=ax2)
ax1.legend_.remove()
ax2.legend_.remove()

# %% [markdown]
# ### distplot
#
# Plot univariate distribution

# %%
for col in 'xy':
#'rug': Rug plots are little dashes drawn beneath the density that show precisely where each data point falls
    sns.distplot(data[col], rug=True)
plt.legend(labels=['x','y'])

# %% [markdown]
# ### swarmplot

# %%
plt.figure(figsize=(10,10))
df = pd.DataFrame({'randomint':np.random.randint(0,100,100),'label':np.random.randint(0,10,100)})
sns.swarmplot(x='label',y='randomint',data=df)

# %% [markdown]
# ### stripplot

# %%
plt.figure(figsize=(12, 8))
sns.stripplot(x='label',
                  y='randomint',
                  data=df)

# %%
sns.kdeplot(data,shade=True)
# Out:
# /Users/jacky/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %% [markdown]
# ### jointplot

# %%
sns.jointplot(x='x',y='y',data=data,kind='kde')

# %% [markdown]
# ### pairplot

# %%
iris=sns.load_dataset('iris')
sns.pairplot(data=iris,hue='species',size=2.5)
# Out:
# /Users/jacky/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
iris_corr = iris.iloc[:, :-1].corr()

sns.set(font_scale=2)
blue_pal = sns.light_palette("steelblue", as_cmap=True)
sns.heatmap(iris_corr, annot=True, cmap=blue_pal,
            cbar=False, linewidth=2, linecolor='yellow')

# %%
tips['day'].unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %% [markdown]
# ### FacetGrid

# %%
# FacetGrid Multi-plot grid for plotting conditional relationships.
# map的x,y別指定 因為tip_pct是呼叫原本的tips 原本的樣子應該是tips['tip_pct']
tips = sns.load_dataset('tips')
tips['tip_pct'] = 100*tips['tip']/tips['total_bill']
grid = sns.FacetGrid(tips, row='sex', col='time', margin_titles=True, hue='day')
grid.map(plt.hist,'tip_pct',bins=np.linspace(0,40,15))

# %% [markdown]
# ### factorplot

# %%
titanic = sns.load_dataset('titanic')
sns.factorplot(x='pclass',
                y='survived',
                hue='sex',
                data=titanic)
# Out:
# /anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# ### pointplot

# %%
sns.pointplot(x='class',
                   y='survived',
                   hue='sex',
                   data=titanic,
                   palette={'male':'g', 
                                'female':'m'},
                   markers=['^', 'o'],
                   linestyles=['-', '--'])

# %% [markdown]
# ### catplot

# %%
with sns.axes_style(style='ticks'):
    g = sns.catplot(x='day',y='total_bill',hue='sex',data=tips,kind='box')
    g.set_axis_labels('Day','Total_bill')

# %%
planets = sns.load_dataset('planets')
# aspect : Aspect ratio of each facet
# aspect x,y軸的比例 x軸是y軸的2倍
with sns.axes_style('white'):
    g = sns.catplot(x='year', data=planets, aspect=2,
                    kind='count', color='steelblue')
    g.set_xticklabels(step=5)

# %%
plt.figure(figsize=(20, 10))
with sns.axes_style('white'):
    plt.figure(figsize=(20, 20))
    g = sns.catplot(x='year', data=planets, aspect=2, col='number', col_wrap=3,
                    kind='count', hue='method', order=range(2001, 2015))

# %% [markdown]
# ### lineplot

# %%
plt.figure(figsize=(10, 10))
# units: Grouping variable identifying sampling units.
# units 當您使用重複測量數據（即，您有多次採樣的單位）時，您還可以單獨繪製每個採樣單位，而無需通過語義區分它們。這可以避免使圖例混亂
# estimator: 要完全剔除聚合效應，請將estimator參數設置為None  If ``None``, all observations will be drawn.    
sns.lineplot(x='year', y='distance', hue='method',
             palette='Set2', data=planets, linewidth=4, units='mass', estimator=None)
plt.legend(loc='upper left', frameon=True,
           framealpha=2, borderpad=1, edgecolor='black')

# %% [markdown]
# ### violinplot

# %%
sns.violinplot(x='age',
                  y='sex',
                  data=titanic,
                  hue='survived')

# %% [markdown]
# ### heatmap

# %%
#Make a diverging palette between two HUSL colors.
#h_neg,h_pos: Anchor hues for negative and positive extents of the map.
#center:Whether the center of the palette is light or dark.
color_palette = sns.diverging_palette(h_neg=250, h_pos=0, center='dark', as_cmap=True)
planets_adjust = planets.iloc[:, 1:-1].corr()
#vmin,vmax:Values to anchor the colormap,
#The value at which to center the colormap when plotting divergant data.
sns.heatmap(planets_adjust, center=0.5, vmin=0,
            vmax=1, annot=True, cmap=color_palette)

# %% [markdown]
# ### jointplot

# %%
i = sns.load_dataset('iris')
sns.jointplot(x='sepal_length',
                 y='sepal_width',
                 data=i,
                 kind='kde')

# %% [markdown]
# ### JointGrid

# %%
i = sns.JointGrid(
            x='x',
            y='y',
            data=data)

i = i.plot(sns.regplot,
            sns.distplot)

# %%
#"col_wrap": the column variable at this width
#'col' :Variables that define subsets of the data
df = pd.DataFrame({'hello': np.arange(5), 'world': np.random.randint(
    10, 20, 5), 'name': ['Jacky', 'Wendy', 'Jacky', 'Amy', 'Me']})
g = sns.FacetGrid(data=df, col='name',col_wrap=3)
g.map(plt.scatter, x='hello', y='world')

# %%
# sns.light_palette(): Make a sequential palette that blends from light to ``color``.
blue_scale = sns.light_palette(color='steelblue')
# sns.palplot(): Plot the values in a color palette as a horizontal array.
sns.palplot(pal=blue_scale)

# %%
# sns.dark_palette(): Make a sequential palette that blends from dark to ``color``.
red_scale = sns.dark_palette(color='orangered')
sns.palplot(pal=red_scale)

# %%
colorbrewer_palettes = ['Reds', 'Blues', 'YlOrBr', 'PuBuGn', 'GnBu', 'Greys']
for i, pal in enumerate(colorbrewer_palettes):
    sns.palplot(pal=sns.color_palette(pal, n_colors=i+4))
    plt.title(pal)

# %%
colorbrewer_palettes = ['Set1', 'Set2', 'Set3',
                        'Accent', 'Paired', 'Pastel1', 'Pastel2', 'Dark2']
for pal in colorbrewer_palettes:
    sns.palplot(pal=sns.color_palette(pal))
    plt.title(pal, loc='left')
